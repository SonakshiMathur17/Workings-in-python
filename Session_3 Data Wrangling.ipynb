# %% [markdown]
# # Session 3: Data Wrangling

# %%
import pandas as pd

# %% [markdown]
# ## Accessing data

# %%
df=pd.read_csv('Session_3_data.csv')
df
# Out:
#    Region  Year Quarter ProductCategory  Sales
# 0   North  2020      Q1     Electronics  20000
# 1   North  2020      Q2     Electronics  25000
# 2   North  2020      Q1       Furniture   6000
# 3   North  2020      Q2       Furniture   7000
# 4   North  2021      Q1     Electronics  30000
# 5   North  2021      Q2     Electronics  23000
# 6   North  2021      Q1       Furniture   8000
# 7   North  2021      Q2       Furniture   7000
# 8   South  2020      Q1     Electronics  15000
# 9   South  2020      Q2     Electronics  32000
# 10  South  2020      Q1       Furniture  10000
# 11  South  2020      Q2       Furniture   9000
# 12  South  2021      Q1     Electronics  28000
# 13  South  2021      Q2     Electronics  23000
# 14  South  2021      Q1       Furniture   9000
# 15  South  2021      Q2       Furniture  10500
# 16   East  2020      Q1        Clothing  12000
# 17   East  2020      Q2        Clothing  18000
# 18   East  2021      Q1        Clothing  22000
# 19   East  2021      Q2        Clothing  25000
# 20   West  2020      Q1        Clothing  13000
# 21   West  2020      Q2        Clothing  14000
# 22   West  2021      Q1        Clothing  24000
# 23   West  2021      Q2        Clothing  22000

# %%
df.columns
# Out:
# Index(['Region', 'Year', 'Quarter', 'ProductCategory', 'Sales'], dtype='object')

# %%
df['Region'].value_counts()
# Out:
# Region
# North    8
# South    8
# East     4
# West     4
# Name: count, dtype: int64

# %%
df['Year'].value_counts()
# Out:
# Year
# 2020    12
# 2021    12
# Name: count, dtype: int64

# %%
df['Quarter'].value_counts()
# Out:
# Quarter
# Q1    12
# Q2    12
# Name: count, dtype: int64

# %%
df['ProductCategory'].value_counts()
# Out:
# ProductCategory
# Electronics    8
# Furniture      8
# Clothing       8
# Name: count, dtype: int64

# %% [markdown]
# ## Creating multi-level indexing

# %%
df.set_index(['Region','Year','Quarter','ProductCategory'],inplace=True)
df
# Out:
#                                      Sales
# Region Year Quarter ProductCategory
# North  2020 Q1      Electronics      20000
#             Q2      Electronics      25000
#             Q1      Furniture         6000
#             Q2      Furniture         7000
#        2021 Q1      Electronics      30000
#             Q2      Electronics      23000
#             Q1      Furniture         8000
#             Q2      Furniture         7000
# South  2020 Q1      Electronics      15000
#             Q2      Electronics      32000
#             Q1      Furniture        10000
#             Q2      Furniture         9000
#        2021 Q1      Electronics      28000
#             Q2      Electronics      23000
#             Q1      Furniture         9000
#             Q2      Furniture        10500
# East   2020 Q1      Clothing         12000
#             Q2      Clothing         18000
#        2021 Q1      Clothing         22000
#             Q2      Clothing         25000
# West   2020 Q1      Clothing         13000
#             Q2      Clothing         14000
#        2021 Q1      Clothing         24000
#             Q2      Clothing         22000

# %%
df.columns
# Out:
# Index(['Sales'], dtype='object')

# %% [markdown]
# ## Analysis

# %%
# 1. Display the index names.
df.index.names
# Out:
# FrozenList(['Region', 'Year', 'Quarter', 'ProductCategory'])

# %%
# 2. Display data for the ‘North’ region

df.loc['North']
# Out:
#                               Sales
# Year Quarter ProductCategory
# 2020 Q1      Electronics      20000
#      Q2      Electronics      25000
#      Q1      Furniture         6000
#      Q2      Furniture         7000
# 2021 Q1      Electronics      30000
#      Q2      Electronics      23000
#      Q1      Furniture         8000
#      Q2      Furniture         7000

# %%
# 3. Display data for the ‘South’ region.

df.loc['South']
# Out:
#                               Sales
# Year Quarter ProductCategory
# 2020 Q1      Electronics      15000
#      Q2      Electronics      32000
#      Q1      Furniture        10000
#      Q2      Furniture         9000
# 2021 Q1      Electronics      28000
#      Q2      Electronics      23000
#      Q1      Furniture         9000
#      Q2      Furniture        10500

# %%
# 4. Display data for the year 2020

df.loc[2020]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2020
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 3
#       1 # 4. Display data for the year 2020
# ----> 3 df.loc[2020]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4228, in NDFrame.xs(self, key, axis, level, drop_level)
#    4225     index = self.index
#    4227 if isinstance(index, MultiIndex):
# -> 4228     loc, new_index = index._get_loc_level(key, level=0)
#    4229     if not drop_level:
#    4230         if lib.is_integer(loc):
#    4231             # Slice index must be an integer or None
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3175, in MultiIndex._get_loc_level(self, key, level)
#    3173         return indexer, maybe_mi_droplevels(indexer, ilevels)
#    3174 else:
# -> 3175     indexer = self._get_level_indexer(key, level=level)
#    3176     if (
#    3177         isinstance(key, str)
#    3178         and self.levels[level]._supports_partial_string_indexing
#    3179     ):
#    3180         # check to see if we did an exact lookup vs sliced
#    3181         check = self.levels[level].get_loc(key)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3276, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3273         return slice(i, j, step)
#    3275 else:
# -> 3276     idx = self._get_loc_single_level_index(level_index, key)
#    3278     if level > 0 or self._lexsort_depth == 0:
#    3279         # Desired level is not sorted
#    3280         if isinstance(idx, slice):
#    3281             # test_get_loc_partial_timestamp_multiindex
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/multi.py:2865, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2863     return -1
#    2864 else:
# -> 2865     return level_index.get_loc(key)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 2020

# %%
df.loc[:,2020,:,:]
# Out:
#                                 Sales
# Region Quarter ProductCategory
# North  Q1      Electronics      20000
#        Q2      Electronics      25000
#        Q1      Furniture         6000
#        Q2      Furniture         7000
# South  Q1      Electronics      15000
#        Q2      Electronics      32000
#        Q1      Furniture        10000
#        Q2      Furniture         9000
# East   Q1      Clothing         12000
#        Q2      Clothing         18000
# West   Q1      Clothing         13000
#        Q2      Clothing         14000

# %%
# 5. Display data for quarter ‘Q2’

df.loc[:,:,'Q2',:]
# Out:
#                              Sales
# Region Year ProductCategory
# North  2020 Electronics      25000
#             Furniture         7000
#        2021 Electronics      23000
#             Furniture         7000
# South  2020 Electronics      32000
#             Furniture         9000
#        2021 Electronics      23000
#             Furniture        10500
# East   2020 Clothing         18000
#        2021 Clothing         25000
# West   2020 Clothing         14000
#        2021 Clothing         22000

# %%
df.loc[slice(None),slice(None),'Q2',slice(None)]
# Out:
#                              Sales
# Region Year ProductCategory
# North  2020 Electronics      25000
#             Furniture         7000
#        2021 Electronics      23000
#             Furniture         7000
# South  2020 Electronics      32000
#             Furniture         9000
#        2021 Electronics      23000
#             Furniture        10500
# East   2020 Clothing         18000
#        2021 Clothing         25000
# West   2020 Clothing         14000
#        2021 Clothing         22000

# %%
# cross section .xs

df.xs(level='Quarter',key='Q2')
# Out:
#                              Sales
# Region Year ProductCategory
# North  2020 Electronics      25000
#             Furniture         7000
#        2021 Electronics      23000
#             Furniture         7000
# South  2020 Electronics      32000
#             Furniture         9000
#        2021 Electronics      23000
#             Furniture        10500
# East   2020 Clothing         18000
#        2021 Clothing         25000
# West   2020 Clothing         14000
#        2021 Clothing         22000

# %%
# 6. Find the total sales for each year

df.groupby(level='Year').sum()
# Out:
#        Sales
# Year
# 2020  181000
# 2021  231500

# %%
# 7. Find the mean Sales for each ProductCategory

df.groupby(level='ProductCategory').mean()
# Out:
#                    Sales
# ProductCategory
# Clothing         18750.0
# Electronics      24500.0
# Furniture         8312.5

# %%
# 8. Find the Sales for Electronics in North region in 2020 
df.loc['North',2020,:,'Electronics']
# Out:
#          Sales
# Quarter
# Q1       20000
# Q2       25000

# %%
# 9. Find average Sales for Electronics in North region in 2020
df.loc['North',2020,:,'Electronics'].mean()
# Out:
# Sales    22500.0
# dtype: float64

# %%
# 10. Which ProductCategory had more Sales in the South region for Q2 of 2021?

df.loc['South',2021,'Q2',:]
# Out:
#                  Sales
# ProductCategory
# Electronics      23000
# Furniture        10500

# %%
df.loc['South',2021,'Q2',:].max()
# Out:
# Sales    23000
# dtype: int64

# %%
df.loc['South',2021,'Q2',:].idxmax()
# Out:
# Sales    Electronics
# dtype: object

# %%
# 11. What is the total sales for Furniture across all regions in 2020?

df.loc[:,2020,:,'Furniture']
# Out:
#                 Sales
# Region Quarter
# North  Q1        6000
#        Q2        7000
# South  Q1       10000
#        Q2        9000

# %%
df.loc[:,2020,:,'Furniture'].sum()
# Out:
# Sales    32000
# dtype: int64

# %%
# 12. Find sales of all product categories  in the West region for Q2 of 2020.

df.loc['West',2020,'Q2',:]
# Out:
#                  Sales
# ProductCategory
# Clothing         14000

# %%
# 13. Which region had the highest sales in Electronics in 2020?

df.loc[:,2020,:,'Electronics']
# Out:
#                 Sales
# Region Quarter
# North  Q1       20000
#        Q2       25000
# South  Q1       15000
#        Q2       32000

# %%
df.loc[:,2020,:,'Electronics'].groupby('Region').sum()
# Out:
#         Sales
# Region
# North   45000
# South   47000

# %%
df.loc[:,2020,:,'Electronics'].groupby('Region').sum().idxmax()
# Out:
# Sales    South
# dtype: object

# %%
# 14. Find Total sales for North region in 2021 across all product categories
df.loc['North',2021,:,:].sum()
# Out:
# Sales    68000
# dtype: int64

# %% [markdown]
# ## Merging of DFs

# %%
df1=pd.DataFrame({'key':['a','a','b','b','c','d'],
                  'value1':[1,2,3,4,5,6]})
df1
# Out:
#   key  value1
# 0   a       1
# 1   a       2
# 2   b       3
# 3   b       4
# 4   c       5
# 5   d       6

# %%
df2=pd.DataFrame({'key':['a','a','b'],
                 'value2':[10,20,30]})
df2
# Out:
#   key  value2
# 0   a      10
# 1   a      20
# 2   b      30

# %% [markdown]
# ### Merging with a common column

# %%
pd.merge(df1,df2)
# Out:
#   key  value1  value2
# 0   a       1      10
# 1   a       1      20
# 2   a       2      10
# 3   a       2      20
# 4   b       3      30
# 5   b       4      30

# %% [markdown]
# ### Using on

# %%
pd.merge(df1,df2,on='key')
# Out:
#   key  value1  value2
# 0   a       1      10
# 1   a       1      20
# 2   a       2      10
# 3   a       2      20
# 4   b       3      30
# 5   b       4      30

# %% [markdown]
# ## Using how

# %%
pd.merge(df1,df2,on='key',how='inner')
# Out:
#   key  value1  value2
# 0   a       1      10
# 1   a       1      20
# 2   a       2      10
# 3   a       2      20
# 4   b       3      30
# 5   b       4      30

# %%
pd.merge(df1,df2,on='key',how='outer')
# Out:
#   key  value1  value2
# 0   a       1    10.0
# 1   a       1    20.0
# 2   a       2    10.0
# 3   a       2    20.0
# 4   b       3    30.0
# 5   b       4    30.0
# 6   c       5     NaN
# 7   d       6     NaN

# %%
pd.merge(df1,df2,on='key',how='left')
# Out:
#   key  value1  value2
# 0   a       1    10.0
# 1   a       1    20.0
# 2   a       2    10.0
# 3   a       2    20.0
# 4   b       3    30.0
# 5   b       4    30.0
# 6   c       5     NaN
# 7   d       6     NaN

# %%
pd.merge(df1,df2,on='key',how='right')
# Out:
#   key  value1  value2
# 0   a       1      10
# 1   a       2      10
# 2   a       1      20
# 3   a       2      20
# 4   b       3      30
# 5   b       4      30

# %% [markdown]
# ### Merging without a common column

# %%
df3=pd.DataFrame({'key1':['a','a','b','b','c','d'],
                  'value1':[1,2,3,4,5,6]})
df3
# Out:
#   key1  value1
# 0    a       1
# 1    a       2
# 2    b       3
# 3    b       4
# 4    c       5
# 5    d       6

# %%
df4=pd.DataFrame({'key2':['a','a','b'],
                 'value2':[10,20,30]})
df4
# Out:
#   key2  value2
# 0    a      10
# 1    a      20
# 2    b      30

# %%
pd.merge(df3,df4)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 pd.merge(df3,df4)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:169, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     154     return _cross_merge(
#     155         left_df,
#     156         right_df,
#    (...)
#     166         copy=copy,
#     167     )
#     168 else:
# --> 169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#     172         how=how,
#     173         on=on,
#     174         left_on=left_on,
#     175         right_on=right_on,
#     176         left_index=left_index,
#     177         right_index=right_index,
#     178         sort=sort,
#     179         suffixes=suffixes,
#     180         indicator=indicator,
#     181         validate=validate,
#     182     )
#     183     return op.get_result(copy=copy)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:783, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     776     msg = (
#     777         "Not allowed to merge between different levels. "
#     778         f"({_left.columns.nlevels} levels on the left, "
#     779         f"{_right.columns.nlevels} on the right)"
#     780     )
#     781     raise MergeError(msg)
# --> 783 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     785 (
#     786     self.left_join_keys,
#     787     self.right_join_keys,
#    (...)
#     790     right_drop,
#     791 ) = self._get_merge_keys()
#     793 if left_drop:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:1538, in _MergeOperation._validate_left_right_on(self, left_on, right_on)
#    1536 common_cols = left_cols.intersection(right_cols)
#    1537 if len(common_cols) == 0:
# -> 1538     raise MergeError(
#    1539         "No common columns to perform merge on. "
#    1540         f"Merge options: left_on={left_on}, "
#    1541         f"right_on={right_on}, "
#    1542         f"left_index={self.left_index}, "
#    1543         f"right_index={self.right_index}"
#    1544     )
#    1545 if (
#    1546     not left_cols.join(common_cols, how="inner").is_unique
#    1547     or not right_cols.join(common_cols, how="inner").is_unique
#    1548 ):
#    1549     raise MergeError(f"Data columns not unique: {repr(common_cols)}")
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
pd.merge(df3,df4,left_on='key1',right_on='key2')
# Out:
#   key1  value1 key2  value2
# 0    a       1    a      10
# 1    a       1    a      20
# 2    a       2    a      10
# 3    a       2    a      20
# 4    b       3    b      30
# 5    b       4    b      30

# %%
pd.merge(df4,df3,left_on='key2',right_on='key1')
# Out:
#   key2  value2 key1  value1
# 0    a      10    a       1
# 1    a      10    a       2
# 2    a      20    a       1
# 3    a      20    a       2
# 4    b      30    b       3
# 5    b      30    b       4
